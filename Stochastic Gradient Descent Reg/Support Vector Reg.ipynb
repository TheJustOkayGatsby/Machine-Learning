# %% [markdown]
# <a href="https://colab.research.google.com/github/TheJustOkayGatsby/Machine-Learning/blob/main/Stochastic%20Gradient%20Descent%20Reg/Support%20Vector%20Reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import  read_csv, DataFrame,Series
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
#from sklearn import linear_model
from sklearn.linear_model import SGDRegressor
from plotly import graph_objs, figure_factory

# reading and metadata
data1 = read_csv("/content/drive/MyDrive/DBS Lectures /PricePrediction.csv")
#print(data1.head(2))
print(data1.shape)
print(data1.info())
# # # # print(data1.describe())
# Out:
# (1460, 22)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   LotArea         1460 non-null   int64
#  1   YearBuilt       1460 non-null   int64
#  2   YearRemodelled  1460 non-null   int64
#  3   TotalBsmtSF     1460 non-null   int64
#  4   CentralAir      1460 non-null   object
#  5   1stFlrSF        1460 non-null   int64
#  6   2ndFlrSF        1460 non-null   int64
#  7   GrLivArea       1460 non-null   int64
#  8   BsmtFullBath    1460 non-null   int64
#  9   BsmtHalfBath    1460 non-null   int64
#  10  FullBath        1460 non-null   int64
#  11  HalfBath        1460 non-null   int64
#  12  BedroomAbvGr    1460 non-null   int64
#  13  KitchenAbvGr    1460 non-null   int64
#  14  TotRmsAbvGrd    1460 non-null   int64
#  15  Fireplaces      1460 non-null   int64
#  16  GarageCars      1460 non-null   int64
# ...

# %%
# catagorical columns
# DataFrame(data1['CentralAir'])
# data1['CentralAir'].unique()
# DataFrame(data1['PavedDrive'])
# data1['PavedDrive'].unique()
# Out:
# 0       Y
# 1       Y
# 2       Y
# 3       Y
# 4       Y
#        ..
# 1455    Y
# 1456    Y
# 1457    Y
# 1458    Y
# 1459    Y
# Name: CentralAir, Length: 1460, dtype: object

# %%
# Encoding
data1['CentralAir'] = data1['CentralAir'].map({'Y':1,'N':0})
data1['PavedDrive'] = data1['PavedDrive'].map({'Y':1,'N':0,'P':1})
print(data1.info())
data1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   LotArea         1460 non-null   int64
#  1   YearBuilt       1460 non-null   int64
#  2   YearRemodelled  1460 non-null   int64
#  3   TotalBsmtSF     1460 non-null   int64
#  4   CentralAir      1460 non-null   int64
#  5   1stFlrSF        1460 non-null   int64
#  6   2ndFlrSF        1460 non-null   int64
#  7   GrLivArea       1460 non-null   int64
#  8   BsmtFullBath    1460 non-null   int64
#  9   BsmtHalfBath    1460 non-null   int64
#  10  FullBath        1460 non-null   int64
#  11  HalfBath        1460 non-null   int64
#  12  BedroomAbvGr    1460 non-null   int64
#  13  KitchenAbvGr    1460 non-null   int64
#  14  TotRmsAbvGrd    1460 non-null   int64
#  15  Fireplaces      1460 non-null   int64
#  16  GarageCars      1460 non-null   int64
# ...

# %%
#  Heatmap
correlation1  = data1.corr()
f = figure_factory.create_annotated_heatmap(correlation1.values,list(correlation1.columns),list(correlation1.columns),correlation1.round(2).values,showscale=False)
f.show()
data2 = data1.drop(['TotRmsAbvGrd','GarageCars'], axis = 1)
data2.info()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Dividing dataset into label and feature sets
X = data2.drop(['SalePrice'], axis = 1) # Features
Y = data2['SalePrice'] # Labels
print(X.shape)
print(Y.shape)
# Out:
# (1460, 19)
# (1460,)

# %%
# data Scaling
X_ = StandardScaler().fit_transform(X)

# %%
#Modified mean square error
# r=X_.shape[0]
# c=X_.shape[1]
r,c=X_.shape
print(X_.shape)
print(r,c)
print((cv-1)/cv*r,c)
modified_r2 = 1-(1-best_result)*((cv-1)/cv*r-1)/((cv-1)/cv*r-c-1)# 4/5*r is number of rows in training set, c is number of columns
print("modified_r2: ", modified_r2)
# Out:
# (1460, 19)
# 1460 19
# 1445.4 19
# modified_r2:  0.7427473946897756

# %%
# #Support Vector Regression
# from sklearn.svm import SVR
# SVRegressor = SVR()
# Hparameters = {'kernel': ['linear', 'poly', 'rbf', 'sigmoid'], 'C': [100,1000,10000], 'epsilon': [100,1000,10000]}
# grid_search1 = GridSearchCV(estimator=SVRegressor, param_grid=Hparameters, scoring='r2', cv=5)
# grid_search1.fit(X_, Y)

# best_parameters = grid_search1.best_params_
# print("Best parameters: ", best_parameters)
# best_result = grid_search1.best_score_
# print("Best result: ", best_result)
